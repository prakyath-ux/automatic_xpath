# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv("xpaths_export.csv")

# %%
df
# Out:
#                         label  \
# 0                   firstName
# 1                   firstName
# 2                       email
# 3                       email
# 4                  middleName
# 5                  middleName
# 6                mobileNumber
# 7                mobileNumber
# 8                    lastName
# 9                    lastName
# 10              Select Branch
# 11  200 - TECU - COUVA BRANCH
# 12            Save & Continue
#
#                                                 xpath          strategy  \
# 0                                //*[@id="firstName"]                id
# 1                                //*[@id="firstName"]                id
# 2                                    //*[@id="email"]                id
# 3                                    //*[@id="email"]                id
# 4                               //*[@id="middleName"]                id
# 5                               //*[@id="middleName"]                id
# ...
