# %%
import pandas as pd

# %%
df = pd.read_csv("xpaths_20260127_133601.csv")

# %%
df
# Out:
#                             Label  \
# 0                           email
# 1                           email
# 2                       firstName
# 3                       firstName
# 4                      middleName
# 5                      middleName
# 6                        lastName
# 7                        lastName
# 8                    mobileNumber
# 9                    mobileNumber
# 10                  Select Branch
# 11                      FLOW BILL
# 12            Add profile picture
# 13                         Upload
# 14                    file-upload
# 15                    file-upload
# 16                Save & Continue
# 17                    otp-input-0
# 18                    otp-input-0
# 19                    otp-input-1
# 20                    otp-input-2
# 21                    otp-input-3
# 22                    otp-input-4
# 23                    otp-input-5
# 24                     Verify OTP
# 25            1. First form of ID
# ...
