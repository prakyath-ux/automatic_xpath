# %%
import pandas as pd

# %%
df = pd.read_csv("xpaths_20260127_175205.csv")

# %%
df = df[["Label", "Action", "Value"]]

# %%
df
# Out:
#                                       Label  Action  \
# 0                                 firstName   click
# 1                                 firstName  change
# 2                                     email   click
# 3                                     email  change
# 4                                middleName   click
# ..                                      ...     ...
# 242  1.-job-letter-(less-than-3-months-old)  change
# 243                             Select File   click
# 244     2.-pay-slip-(less-than-1-month-old)   click
# 245     2.-pay-slip-(less-than-1-month-old)  change
# 246                                  Submit   click
#
#                             Value
# 0                             NaN
# 1                          LOKESH
# 2                             NaN
# 3        DIFAYQEID128@OKEXBIT.COM
# 4                             NaN
# ..                            ...
# 242  C:\fakepath\AVINASH_PASS.png
# 243                           NaN
# 244                           NaN
# 245     C:\fakepath\DAVID_N_B.png
# 246                           NaN
#
# [247 rows x 3 columns]

# %%
# Step 1: Clean data
df_clean = df[['Label', 'Action', 'Value']].copy()

# Step 2: Replace NaN with 'Click' for click actions
df_clean['Value'] = df_clean.apply(
    lambda row: 'Click' if row['Action'] == 'click' else row['Value'],
    axis=1
)

# Step 3: Build the three rows
labels = df_clean['Label'].tolist()
actions = df_clean['Action'].tolist()
values = df_clean['Value'].tolist()

# Step 4: Create result dataframe
rows = [
    ['Description'] + labels,           # Row 0: Header
    ['Action'] + actions,               # Row 1: Actions
    ['TestCase_001'] + values  # Row 2: Values
]

result = pd.DataFrame(rows)
# Show all columns
pd.set_option('display.max_columns', None)

# Optional: also expand column width
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)









result
# Out:
#             0          1          2      3                         4    \
# 0   Description  firstName  firstName  email                     email
# 1        Action      click     change  click                    change
# 2  TestCase_001      Click     LOKESH  Click  DIFAYQEID128@OKEXBIT.COM
#
#           5           6             7             8         9         10   \
# 0  middleName  middleName  mobileNumber  mobileNumber  lastName  lastName
# 1       click      change         click        change     click    change
# 2       Click           M         Click      785-6321     Click      CHAN
#
#                 11     12                   13      14           15   \
# 0  Choose an option    Son  Add profile picture  Upload  file-upload
# 1             click  click                click   click        click
# 2             Click  Click                Click   Click        Click
#
#                                                    16               17   \
# 0                                          file-upload  Save & Continue
# 1                                               change            click
# 2  C:\fakepath\Screenshot 2026-01-27 at 1.02.56 PM.png            Click
#
#            18           19           20           21           22   \
# 0  otp-input-0  otp-input-0  otp-input-1  otp-input-2  otp-input-3
# 1        click       change       change       change       change
# 2        Click            1            2            1            2
#
#            23           24          25      26           27   \
# 0  otp-input-4  otp-input-5  Verify OTP  Spouse  Select File
# 1       change       change       click   click        click
# 2            1            2       Click   Click        Click
#
#                   28                        29        30                 31   \
# 0  upload-front-input        upload-front-input  Continue  Upload Back of ID
# 1               click                    change     click              click
# 2               Click  C:\fakepath\FlowBill.jpg     Click              Click
#
#                  32                         33                34   \
# 0  upload-back-input          upload-back-input  Choose an option
# 1              click                     change             click
# 2              Click  C:\fakepath\DAVID_N_B.png             Click
#
#            35           36     37                             38   \
# 0  mailingCity  mailingCity    div  permanentAddressSameAsMailing
# 1        click       change  click                          click
# 2        Click     TRINCITY  Click                          Click
#
#                              39     40                41                42   \
# 0  permanentAddressSameAsMailing    div  utilityDocOption  utilityDocOption
# 1                         change  click             click            change
# 2                           true  Click             Click              true
#
#                  43                        44               45         46   \
# 0  Save and Continue  Select Employment Status  Select Employer  :rt:-year
# 1              click                     click            click      click
# 2              Click                     Click            Click      Click
#
#           47          48             49                      50   \
# 0  occupation  occupation  Choose sector  Choose Employment Type
# 1       click      change          click                   click
# 2       Click    ENGINEER          Click                   Click
#
#                     51                    52            53            54   \
# 0  employerAddressLine1  employerAddressLine1  employerCity  employerCity
# 1                 click                change         click        change
# 2                 Click        1 NORTHAM ROAD         Click      TRINCITY
#
#               55           56           57                58   \
# 0  Choose Country  workPhoneNo  workPhoneNo  Choose an option
# 1           click        click       change             click
# 2           Click        Click     123-4567             Click
#
#                 59      60           61              62     63   \
# 0  Salary Frequency  salary       salary  Account Funded    div
# 1             click   click       change           click  click
# 2             Click   Click  $ 13,000.00           Click  Click
#
#                    64                   65                66            67   \
# 0  nationalOfTTPrimary  nationalOfTTPrimary  Country of birth  placeOfBirth
# 1                click               change             click         click
# 2                Click                 true             Click         Click
#
#             68     69                     70                     71   \
# 0  placeOfBirth    div  nationalOfTTSecondary  nationalOfTTSecondary
# 1        change  click                  click                 change
# 2      TRINCITY  Click                  Click                   true
#
#               72      73                          74                    75   \
# 0  Marital Status  SINGLE  Highest Level of Education  Communication Method
# 1           click   click                       click                 click
# 2           Click   Click                       Click                 Click
#
#      76                        77                        78     79   \
# 0    div  memberOfOtherCreditUnion  memberOfOtherCreditUnion    div
# 1  click                     click                    change  click
# 2  Click                     Click                     false  Click
#
#               80              81     82            83                    84   \
# 0  hasBeneficiary  hasBeneficiary    div  documentType          documentType
# 1           click          change  click         click                change
# 2           Click            true  Click         Click  BENEFICIARY-PASSPORT
#
#                85            86                            87   \
# 0  Select Document  upload-input                  upload-input
# 1            click         click                        change
# 2            Click         Click  C:\fakepath\AVINASH_PASS.png
#
#                    88                   89               90     91   \
# 0  beneficiaryMobileNo  beneficiaryMobileNo  Select relation    div
# 1                click               change            click  click
# 2                Click             456-7891            Click  Click
#
#                                  92                                 93   \
# 0  isApplyingForLincuCardApplication  isApplyingForLincuCardApplication
# 1                              click                             change
# 2                              Click                               true
#
#      94                           95                           96     97   \
# 0    div  isApplyingForFipApplication  isApplyingForFipApplication    div
# 1  click                        click                       change  click
# 2  Click                        Click                         true  Click
#
#                                  98                                 99   \
# 0  hadFamilyIndemnityPlanCertificate  hadFamilyIndemnityPlanCertificate
# 1                              click                             change
# 2                              Click                               true
#
#      100                              101                              102  \
# 0    div  presentlyCoveredUnderAnotherFip  presentlyCoveredUnderAnotherFip
# 1  click                            click                           change
# 2  Click                            Click                             true
#
#                  103                104    105                   106  \
# 0  deductionTypeDesc  deductionTypeDesc    div  criticalIllnessRider
# 1              click             change  click                 click
# 2              Click               True  Click                 Click
#
#                     107               108    109  \
# 0  criticalIllnessRider  Choose an option    div
# 1                change             click  click
# 2                  true             Click  Click
#
#                                   110                                 111  \
# 0  receivedMedicalAttentionLast5Years  receivedMedicalAttentionLast5Years
# 1                               click                              change
# 2                               Click                                true
#
#                        112                      113     114    115  \
# 0  medicalAttentionDetails  medicalAttentionDetails  Select    div
# 1                    click                   change   click  click
# 2                    Click               MAJOR BURN   Click  Click
#
#                            116                          117               118  \
# 0  familyMember-0-isTecuMember  familyMember-0-isTecuMember  Choose an option
# 1                        click                       change             click
# 2                        Click                         true             Click
#
#                   119                   120                        121  \
# 0  Upload Front of ID  front-upload-input-0       front-upload-input-0
# 1               click                 click                     change
# 2               Click                 Click  C:\fakepath\DAVID_N_F.png
#
#                  122                  123                        124    125  \
# 0  Upload Back of ID  back-upload-input-0        back-upload-input-0    svg
# 1              click                click                     change  click
# 2              Click                Click  C:\fakepath\DAVID_N_B.png  Click
#
#           126         127         128     129               130    131  \
# 0  customerId  customerId  :r21:-year  Search  Choose an option    div
# 1       click      change       click   click             click  click
# 2       Click      121669       Click   Click             Click  Click
#
#               132             133          134          135    136  \
# 0  hasRecommender  hasRecommender  groupHealth  groupHealth    div
# 1           click          change        click       change  click
# 2           Click            true        Click         True  Click
#
#                           137                         138       139       140  \
# 0  isSpouseCoveredByOtherPlan  isSpouseCoveredByOtherPlan  planName  planName
# 1                       click                      change     click    change
# 2                       Click                        true     Click      TEST
#
#                 141               142          143         144         145  \
# 0  insuranceCompany  insuranceCompany  Select Bank  branchName  branchName
# 1             click            change        click       click      change
# 2             Click               ABC        Click       Click    TRINCITY
#
#          146              147      148          149          150    151  \
# 0  accountNo        accountNo  Savings  accountType  accountType    div
# 1      click           change    click        click       change  click
# 2      Click  547869126466246    Click        Click         true  Click
#
#             152           153    154                       155  \
# 0  addDependent  addDependent    div  dependent-0-isTecuMember
# 1         click        change  click                     click
# 2         Click          true  Click                     Click
#
#                         156    157                       158  \
# 0  dependent-0-isTecuMember    div  dependent-0-isTecuMember
# 1                    change  click                     click
# 2                      true  Click                     Click
#
#                         159    160               161             162  \
# 0  dependent-0-isTecuMember    div  Choose an option  dependentName0
# 1                    change  click             click           click
# 2                     false  Click             Click           Click
#
#            163                 164                           165    166  \
# 0  Select File  dependent-0-upload            dependent-0-upload    div
# 1        click               click                        change  click
# 2        Click               Click  C:\fakepath\AVINASH_PASS.png  Click
#
#            167          168    169                         170  \
# 0  beneficiary  beneficiary    div  beneficiary-0-isTecuMember
# 1        click       change  click                       click
# 2        Click         true  Click                       Click
#
#                           171               172          173  \
# 0  beneficiary-0-isTecuMember  Choose an option  National ID
# 1                      change             click        click
# 2                        true             Click        Click
#
#                   174                              175  \
# 0  Upload Front of ID  beneficiary-0-main-front-upload
# 1               click                            click
# 2               Click                            Click
#
#                                176                177  \
# 0  beneficiary-0-main-front-upload  Upload Back of ID
# 1                           change              click
# 2        C:\fakepath\DAVID_N_F.png              Click
#
#                               178                             179    180  \
# 0  beneficiary-0-main-back-upload  beneficiary-0-main-back-upload    svg
# 1                           click                          change  click
# 2                           Click       C:\fakepath\DAVID_N_B.png  Click
#
#           181                     182                     183  \
# 0  YYYY-MM-DD  beneficiaryPercentage0  beneficiaryPercentage0
# 1       click                   click                  change
# 2       Click                   Click                     100
#
#                        184                      185  \
# 0  isAllInformationCorrect  isAllInformationCorrect
# 1                    click                   change
# 2                    Click                     True
#
#                             186     187    188            189            190  \
# 0  isTermsAndConditionsAccepted  Accept    div  isHeadOfState  isHeadOfState
# 1                         click   click  click          click         change
# 2                         Click   Click  Click          Click           true
#
#      191           192           193    194              195              196  \
# 0    div  isHeadOfGovt  isHeadOfGovt    div  isSenPolitician  isSenPolitician
# 1  click         click        change  click            click           change
# 2  Click         Click         false  Click            Click            false
#
#      197                198                199    200                    201  \
# 0    div  isSenGovtOfficial  isSenGovtOfficial    div  isSenJudicialOfficial
# 1  click              click             change  click                  click
# 2  Click              Click              false  Click                  Click
#
#                      202    203                    204                    205  \
# 0  isSenJudicialOfficial    div  isSenMilitaryOfficial  isSenMilitaryOfficial
# 1                 change  click                  click                 change
# 2                  false  Click                  Click                  false
#
#      206           207           208    209       210       211    212  \
# 0    div  isSenExecSOC  isSenExecSOC    div  isImpPPO  isImpPPO    div
# 1  click         click        change  click     click    change  click
# 2  Click         Click         false  Click     Click     false  Click
#
#                  213                214    215                         216  \
# 0  isImmediateFamily  isImmediateFamily    div  isMemberOfSeniorManagement
# 1              click             change  click                       click
# 2              Click              false  Click                       Click
#
#                           217    218             219             220  \
# 0  isMemberOfSeniorManagement    div  isPepAssociate  isPepAssociate
# 1                      change  click           click          change
# 2                       false  Click           Click           false
#
#                       221                             222    223    224  \
# 0  SOURCE OF FUNDS/WEALTH  ANTICIPATED NATURE OF BUSINESS    svg    svg
# 1                   click                           click  click  click
# 2                   Click                           Click  Click  Click
#
#      225                      226                      227    228  \
# 0    div  isCitizenOfOtherCountry  isCitizenOfOtherCountry    div
# 1  click                    click                   change  click
# 2  Click                    Click                    false  Click
#
#                  229                230    231           232           233  \
# 0  isGreenCardHolder  isGreenCardHolder    div  isGranteePOA  isGranteePOA
# 1              click             change  click         click        change
# 2              Click              false  Click         Click         false
#
#      234                        235                        236    237  \
# 0    div  hasStandingInstructIncome  hasStandingInstructIncome    div
# 1  click                      click                     change  click
# 2  Click                      Click                      false  Click
#
#                         238                       239       240          241  \
# 0  isDisclosureTaxResidency  isDisclosureTaxResidency  View PDF  Select File
# 1                     click                    change     click        click
# 2                     Click                     false     Click        Click
#
#                                       242  \
# 0  1.-job-letter-(less-than-3-months-old)
# 1                                   click
# 2                                   Click
#
#                                       243          244  \
# 0  1.-job-letter-(less-than-3-months-old)  Select File
# 1                                  change        click
# 2            C:\fakepath\AVINASH_PASS.png        Click
#
#                                    245                                  246  \
# 0  2.-pay-slip-(less-than-1-month-old)  2.-pay-slip-(less-than-1-month-old)
# 1                                click                               change
# 2                                Click            C:\fakepath\DAVID_N_B.png
#
#       247
# 0  Submit
# 1   click
# 2   Click
